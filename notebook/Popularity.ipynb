# %% [markdown]
# # 人気度順推薦
# ## 人気度の定義
# * 今回は評価値が高いものを人気が髙い映画とする
# * 人気度の定義は「クリック数が多いもの」「購入が多いもの」「評価値が髙いもの」など複数あり、自社サービスに最も適した定義を利用

# %%
# 親のフォルダのパスを追加
import sys; sys.path.insert(0, '..')
from util.data_loader import DataLoader
from util.metric_calculator import MetricCalculator

# %%
# Movielensのデータの読み込み
data_loader = DataLoader(num_users=1000, num_test_items=5, data_path='../data/ml-10M100K/')
movielens = data_loader.load()
# Out:
#    user_id  movie_id  rating   timestamp             title              genre  \
# 0        1       122     5.0   838985046  Boomerang (1992)  [Comedy, Romance]
# 1      139       122     3.0   974302621  Boomerang (1992)  [Comedy, Romance]
# 2      149       122     2.5  1112342322  Boomerang (1992)  [Comedy, Romance]
# 3      182       122     3.0   943458784  Boomerang (1992)  [Comedy, Romance]
# 4      215       122     4.5  1102493547  Boomerang (1992)  [Comedy, Romance]
#
#                                                  tag
# 0  [dating, nudity (topless - brief), can't remem...
# 1  [dating, nudity (topless - brief), can't remem...
# 2  [dating, nudity (topless - brief), can't remem...
# 3  [dating, nudity (topless - brief), can't remem...
# 4  [dating, nudity (topless - brief), can't remem...
#    movie_id                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# ...

# %%
movielens.train.groupby("user_id").agg({"movie_id": list})["movie_id"]
# Out:
# user_id
# 1       [185, 231, 292, 316, 329, 355, 356, 364, 370, ...
# 2       [110, 260, 590, 648, 733, 736, 780, 786, 802, ...
# 3       [110, 151, 590, 213, 1148, 1246, 1252, 1276, 1...
# 4       [231, 292, 316, 329, 364, 377, 420, 480, 586, ...
# 5       [648, 736, 780, 858, 1073, 1391, 253, 592, 1, ...
#                               ...
# 1048    [370, 589, 786, 1210, 1246, 4995, 5952, 6539, ...
# 1050    [185, 231, 292, 316, 329, 355, 356, 364, 377, ...
# 1051    [260, 376, 648, 733, 736, 780, 786, 802, 1073,...
# 1052    [590, 1246, 1597, 266, 25, 920, 1527, 3578, 12...
# 1053    [356, 589, 110, 260, 1210, 1148, 1408, 6377, 6...
# Name: movie_id, Length: 1000, dtype: object

# %%
movielens.item_content[["movie_id","genre"]].set_index("movie_id")["genre"].to_dict()
# Out:
# {1: ['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy'],
#  2: ['Adventure', 'Children', 'Fantasy'],
#  3: ['Comedy', 'Romance'],
#  4: ['Comedy', 'Drama', 'Romance'],
#  5: ['Comedy'],
#  6: ['Action', 'Crime', 'Thriller'],
#  7: ['Comedy', 'Romance'],
#  8: ['Adventure', 'Children'],
#  9: ['Action'],
#  10: ['Action', 'Adventure', 'Thriller'],
#  11: ['Comedy', 'Drama', 'Romance'],
#  12: ['Comedy', 'Horror'],
#  13: ['Animation', 'Children'],
#  14: ['Drama'],
#  15: ['Action', 'Adventure', 'Romance'],
#  16: ['Crime', 'Drama'],
#  17: ['Comedy', 'Drama', 'Romance'],
#  18: ['Comedy', 'Drama', 'Thriller'],
#  19: ['Comedy'],
#  20: ['Action', 'Comedy', 'Crime', 'Drama', 'Thriller'],
#  21: ['Action', 'Comedy', 'Drama'],
#  22: ['Crime', 'Drama', 'Horror', 'Mystery', 'Thriller'],
#  23: ['Action', 'Crime', 'Thriller'],
#  24: ['Drama', 'Sci-Fi'],
#  25: ['Drama', 'Romance'],
#  26: ['Drama'],
#  27: ['Drama'],
#  28: ['Drama', 'Romance'],
# ...

# %%
movielens.item_content
# Out:
#        movie_id                               title  \
# 0             1                    Toy Story (1995)
# 1             2                      Jumanji (1995)
# 2             3             Grumpier Old Men (1995)
# 3             4            Waiting to Exhale (1995)
# 4             5  Father of the Bride Part II (1995)
# ...         ...                                 ...
# 10676     65088              Bedtime Stories (2008)
# 10677     65091          Manhattan Melodrama (1934)
# 10678     65126                        Choke (2008)
# 10679     65130           Revolutionary Road (2008)
# 10680     65133      Blackadder Back & Forth (1999)
#
#                                                    genre  \
# 0      [Adventure, Animation, Children, Comedy, Fantasy]
# 1                         [Adventure, Children, Fantasy]
# 2                                      [Comedy, Romance]
# 3                               [Comedy, Drama, Romance]
# ...

# %%
import numpy as np
# 評価値が髙い映画の確認
movie_stats = movielens.train.groupby(['movie_id', 'title']).agg({'rating': [np.size, np.mean]})
movie_stats.sort_values(by=('rating', 'mean'), ascending=False).head()
# Out:
#                                                             rating
#                                                               size mean
# movie_id title
# 4095     Cry Freedom (1987)                                    1.0  5.0
# 7227     Trouble with Angels, The (1966)                       1.0  5.0
# 27255    Wind Will Carry Us, The (Bad ma ra khahad bord)...    1.0  5.0
# 4453     Michael Jordan to the Max (2000)                      2.0  5.0
# 3415     Mirror, The (Zerkalo) (1975)                          1.0  5.0

# %%
# しきい値を導入
movie_stats = movielens.train.groupby(['movie_id', 'title']).agg({'rating': [np.size, np.mean,max,min]}) # movieごとの評価
atleast_flg = movie_stats['rating']['size'] >= 50
movies_sorted_by_rating = movie_stats[atleast_flg].sort_values(by=('rating', 'mean'), ascending=False)
movies_sorted_by_rating.head()
# Out:
#                                                      rating                 \
#                                                        size      mean  max
# movie_id title
# 318      Shawshank Redemption, The (1994)             424.0  4.491745  5.0
# 50       Usual Suspects, The (1995)                   334.0  4.459581  5.0
# 912      Casablanca (1942)                            163.0  4.444785  5.0
# 904      Rear Window (1954)                           129.0  4.441860  5.0
# 2019     Seven Samurai (Shichinin no samurai) (1954)  104.0  4.408654  5.0
#
#
#                                                       min
# movie_id title
# 318      Shawshank Redemption, The (1994)             2.0
# 50       Usual Suspects, The (1995)                   1.0
# 912      Casablanca (1942)                            1.0
# 904      Rear Window (1954)                           2.5
# 2019     Seven Samurai (Shichinin no samurai) (1954)  1.0

# %%
# 人気度推薦
from src.popularity import PopularityRecommender
recommender = PopularityRecommender()
recommend_result = recommender.recommend(movielens, minimum_num_rating=100,genre="Comedy") # minimum_num_rating 何人の人から評価を受けているか？

# %%
recommend_result.user2items
# Out:
# defaultdict(list,
#             {139: [750, 1148, 1193, 4973, 1234, 1199, 1247, 4011, 2324, 1230],
#              149: [750, 1148, 1193, 4973, 1234, 1199, 1247, 1136, 4011, 2324],
#              182: [750, 1148, 1199, 4011, 1288, 778, 2502, 1259, 235, 2700],
#              215: [58, 1028, 1073, 1639, 539, 440, 104, 2081, 2671, 2100],
#              281: [750, 1148, 1193, 4973, 1234, 1199, 1247, 1136, 4011, 2324],
#              326: [750, 1148, 1193, 4973, 1234, 1199, 1247, 1136, 4011, 2324],
#              351: [1199, 4011, 1080, 2502, 1278, 4306, 4886, 3897, 6539, 4963],
#              357: [750, 1148, 1193, 4973, 1199, 1247, 4011, 2324, 1197, 608],
#              426: [17, 2502, 1278, 2791, 11, 1073, 112, 2302, 141, 2081],
#              456: [750, 1148, 1193, 4973, 1234, 1199, 1247, 1136, 4011, 2324],
#              459: [750, 1148, 1193, 4973, 1234, 1199, 1247, 2324, 1197, 608],
#              494: [750, 1148, 1193, 4973, 1234, 1199, 1247, 1136, 4011, 2324],
# ...

# %%
from copy import deepcopy
movie_item = deepcopy(movielens.item_content)

# %%
movie_item[movie_item.movie_id==1148]
# Out:
#       movie_id                                        title  \
# 1125      1148  Wallace & Gromit: The Wrong Trousers (1993)
#
#                                      genre  \
# 1125  [Animation, Children, Comedy, Crime]
#
#                                                     tag
# 1125  [aardman, animated, clay, funny, penguin, funn...

# %%
#  評価
metric_calculator = MetricCalculator()
metrics = metric_calculator.calc(
    movielens.test.rating.tolist(), recommend_result.rating.tolist(),
    movielens.test_user2items, recommend_result.user2items, k=10)
print(metrics)
# Out:
# rmse=1.082, Precision@K=0.008, Recall@K=0.027

# %%
# しきい値を変更したときの挙動
for minimum_num_rating in [1, 200]:
    recommend_result = recommender.recommend(movielens, minimum_num_rating=minimum_num_rating)
    metrics = metric_calculator.calc(
        movielens.test.rating.tolist(), recommend_result.rating.tolist(),
        movielens.test_user2items, recommend_result.user2items, k=10)
    print(metrics)
# Out:
# rmse=1.082, Precision@K=0.000, Recall@K=0.000
# rmse=1.082, Precision@K=0.013, Recall@K=0.042
